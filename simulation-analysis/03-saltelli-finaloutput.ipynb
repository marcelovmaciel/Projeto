# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set_style('whitegrid')
sns.set_context('paper')
sns.set_palette("Set1")
import numpy as np

# %%
stdsaltelli5000 = pd.read_csv("data/saltelli5000std.csv")

# %%
stdsaltelli5000["Var"][0] = "N"
stdsaltelli5000 = stdsaltelli5000.set_index("Var")
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(stdsaltelli5000.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &        S1 &   S1\_conf &        ST &   ST\_conf \\
# Var      &           &           &           &           \\
# \midrule
# N        & -0.000105 &  0.003153 &  0.002526 &  0.000578 \\
# n\_issues &  0.289362 &  0.026289 &  0.366176 &  0.022603 \\
# p        &  0.070374 &  0.015140 &  0.103448 &  0.008719 \\
# σ        &  0.421365 &  0.030780 &  0.512525 &  0.030992 \\
# ρ        &  0.103914 &  0.016065 &  0.144819 &  0.012853 \\
# \bottomrule
# \end{tabular}

# %%
indices_5000 = stdsaltelli5000[['S1','ST']]
err_5000 = stdsaltelli5000[['S1_conf','ST_conf']]

# %%
fig, ax = plt.subplots(1, dpi = 200)
indices_5000.plot.bar(yerr=err_5000.values.T,ax=ax)
plt.xticks(rotation = "horizontal",  fontsize = 14, color = "gray", fontweight= "bold")
# ax.set_ylabel("Impacto", labelpad = 5,  fontsize = 14, color = "gray", fontweight= "bold")
ax.set_xlabel(" ")
ax.set_title("Índices Sobol - Caso I", fontsize = 18, color = "gray", fontweight= "bold")

plt.savefig("image/barplotmuto5k.png", dpi = 200)
plt.show()

# %%
mutodf = pd.read_csv("data/muto5000paramsandresults.csv")

# %%
Y = mutodf["Ystd"]

# %%
sns.distplot(Y, kde = False)
plt.ylabel("Frequência")
plt.xlabel("Desvio Padrão dos Pontos Ideais")
plt.savefig("image/distY.png", dpi = 200)
plt.title("Caso I")
plt.show()

# %%
x = np.random.uniform(size=100000)
sns.distplot(x, kde = False);
plt.show()

# %%
mutodf
# Out:
#           N  n_issues         p         σ         ρ      Ystd
# 0      1489         2  0.561514  0.341611  0.028027  0.052960
# 1      4583         2  0.561514  0.341611  0.028027  0.053073
# 2      1489         1  0.561514  0.341611  0.028027  0.077015
# 3      1489         2  0.900479  0.341611  0.028027  0.051937
# 4      1489         2  0.561514  0.255479  0.028027  0.058814
# 5      1489         2  0.561514  0.341611  0.006934  0.025940
# 6      1489         1  0.900479  0.255479  0.006934  0.037738
# 7      4583         2  0.900479  0.255479  0.006934  0.025035
# 8      4583         1  0.561514  0.255479  0.006934  0.038072
# 9      4583         1  0.900479  0.341611  0.006934  0.034451
# 10     4583         1  0.900479  0.255479  0.028027  0.070068
# 11     4583         1  0.900479  0.255479  0.006934  0.031780
# 12     3739         6  0.116514  0.096611  0.078027  0.114965
# 13     2333         6  0.116514  0.096611  0.078027  0.115987
# ...

# %%
"""
g = sns.PairGrid(mutodf, y_vars=["Ystd"], x_vars=["N", "n_issues", "p", "σ", "ρ"])
g.map(sns.regplot, color='k',scatter_kws={'alpha':0.2, 's':4, 'color':'gray'})
#plt.suptitle("Regressão")
#plt.subplots_adjust(top=0.85)
g.savefig("image/regressionplot.png", dpi = 300)
"""
# Out:
# '\ng = sns.PairGrid(mutodf, y_vars=["Ystd"], x_vars=["N", "n_issues", "p", "σ", "ρ"])\ng.map(sns.regplot, color=\'k\',scatter_kws={\'alpha\':0.2, \'s\':4, \'color\':\'gray\'})\n#plt.suptitle("Regressão")\n#plt.subplots_adjust(top=0.85)\ng.savefig("image/regressionplot.png", dpi = 300)\n'

# %%
def saveregressionplot(df,xvar,yvar = "Ystd", typesim = "mutatingo"):

    fig1, ax1 = plt.subplots(1, dpi = 200)
    sns.regplot(xvar, yvar, data = df, scatter_kws={'alpha':0.2, 's':4, 'color':'gray'}, color='k')
    ax1.set_xlabel(xvar,  fontsize = 12, color = "gray", fontweight= "bold")
    ax1.set_ylabel(yvar,  fontsize = 12, color = "gray", fontweight= "bold")
    plt.savefig("image/regression{}{}.png".format(typesim,xvar), dpi = 200)

# %%
for i in list(mutodf.columns.values):
    saveregressionplot(mutodf,i)

# %% [markdown]
# # Now for mutating sigma

# %%
saltelli5kstdmutatingsigma = pd.read_csv("data/saltelli5000stdmutatingsigma.csv")

# %%
saltelli5kstdmutatingsigma
# Out:
#         Var        S1   S1_conf        ST   ST_conf
# 0   size_nw -0.000751  0.002042  0.002899  0.000803
# 1  n_issues  0.271336  0.029388  0.360126  0.022529
# 2         p  0.058529  0.010757  0.102866  0.008774
# 3         σ  0.488301  0.025718  0.615394  0.033938
# 4         ρ  0.044188  0.009783  0.080392  0.006963

# %%
saltelli5kstdmutatingsigma["Var"][0] = "N"
saltelli5kstdmutatingsigma  = saltelli5kstdmutatingsigma.set_index("Var")
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(saltelli5kstdmutatingsigma.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &        S1 &   S1\_conf &        ST &   ST\_conf \\
# Var      &           &           &           &           \\
# \midrule
# N        & -0.000751 &  0.002042 &  0.002899 &  0.000803 \\
# n\_issues &  0.271336 &  0.029388 &  0.360126 &  0.022529 \\
# p        &  0.058529 &  0.010757 &  0.102866 &  0.008774 \\
# σ        &  0.488301 &  0.025718 &  0.615394 &  0.033938 \\
# ρ        &  0.044188 &  0.009783 &  0.080392 &  0.006963 \\
# \bottomrule
# \end{tabular}

# %%
indices_5000sigma = saltelli5kstdmutatingsigma[['S1','ST']]
err_5000sigma = saltelli5kstdmutatingsigma[['S1_conf','ST_conf']]

# %%
fig, ax = plt.subplots(1, dpi = 200)
indices_5000sigma.plot.bar(yerr=err_5000sigma.values.T,ax=ax)
plt.xticks(rotation = "horizontal",  fontsize = 14, color = "gray", fontweight= "bold")
# ax.set_ylabel("Impacto", labelpad = 5,  fontsize = 14, color = "gray", fontweight= "bold")
ax.set_xlabel(" ")
ax.set_title("Índices Sobol- Caso II", fontsize = 18, color = "gray", fontweight= "bold")

plt.savefig("image/barplotmutosigma5k.png", dpi = 200)
plt.show()

# %%
mutodfsigma = pd.read_csv("data/muto5000paramsandresultsmutatingsigma.csv")

# %%
Ysigma = mutodfsigma["Ystd"]

# %%
sns.distplot(Ysigma, kde = False)
plt.ylabel("Frequência")
plt.xlabel("Desvio Padrão dos Pontos Ideais")
plt.savefig("image/distYsigma.png", dpi = 200)
plt.title("Caso II")
plt.show()

# %%
fig,ax =  plt.subplots(1,2, sharey=True)

sns.distplot(Y, kde = False, ax = ax[0])
ax[0].set_xlabel("Desvio Padrão dos Pontos Ideais")
ax[0].set_ylabel('Frequência')
ax[0].set_title("Caso I")

sns.distplot(Ysigma, kde = False, ax = ax[1])
ax[1].set_xlabel("Desvio Padrão dos Pontos Ideais")
ax[1].set_title("Caso II")

fig.subplots_adjust(wspace=0.2)
plt.savefig("image/distYs.png", dpi = 200)

plt.show()

# %%
for i in list(mutodfsigma.columns.values):
    saveregressionplot(mutodfsigma,i, typesim = "mutatingosigma")

# %%
mutodfsigma
# Out:
#           N  n_issues         ρ         σ      Ystd
# 0      1489         2  0.028027  0.341611  0.052715
# 1      4583         2  0.028027  0.341611  0.052019
# 2      1489         1  0.028027  0.341611  0.074975
# 3      1489         2  0.028027  0.341611  0.042755
# 4      1489         2  0.028027  0.255479  0.055924
# 5      1489         2  0.006934  0.341611  0.026334
# 6      1489         1  0.006934  0.255479  0.025555
# 7      4583         2  0.006934  0.255479  0.020457
# 8      4583         1  0.006934  0.255479  0.033679
# 9      4583         1  0.006934  0.341611  0.033380
# 10     4583         1  0.028027  0.255479  0.062188
# 11     4583         1  0.006934  0.255479  0.029883
# 12     3739         6  0.078027  0.096611  0.117225
# 13     2333         6  0.078027  0.096611  0.112805
# 14     3739         6  0.078027  0.096611  0.114777
# 15     3739         6  0.078027  0.096611  0.109284
# 16     3739         6  0.078027  0.010479  0.118054
# ...
