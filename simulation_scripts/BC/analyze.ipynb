# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
result_test = pd.read_csv("output2.csv")

# %%
result_bc = pd.read_csv("output.csv")

# %%
'''
g = sns.tsplot(time = "time", value = "opinion", data= result, unit = "id", err_style="unit_traces")

plt.savefig("BCe03.pdf",dpi = 150)

'''
g = sns.tsplot(time = "time", value = "opinion", data= result_test, unit = "id", err_style="unit_traces")

# plt.savefig("test.pdf",dpi = 150)
# Out:
# /usr/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.tsplot(time = "time", value = "opinion", data= result_bc, unit = "id", err_style="unit_traces")
# Out:
# /usr/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
